# %% [markdown]
# <a href="https://colab.research.google.com/github/RJGiannini/nft-project-group8/blob/main/asset_sales_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import requests
import json
from pprint import pprint

# %%
url = "https://api.opensea.io/api/v1/assets?order_by=sale_price&order_direction=desc&offset=0&limit=50&collection=cryptopunks"

#querystring = {"order_by":"sale_price","order_direction":"desc","offset":"0","limit":"1","collection":"cryptopunks"}

#response = requests.request("GET", url, params=querystring)

#print(response.text)

# %%
JSONContent = requests.get(url).json()

assets = JSONContent["assets"]

#pprint(JSONContent["assets"])

# %%
data = []

# %%
for asset in assets:
  temp = {}
  temp["name"] = asset["name"]
  temp["id"] = asset["id"]
  temp["token_id"] = asset["token_id"]
  temp["num_sales"] = asset["num_sales"]
  temp["total_price"] = asset["last_sale"]["total_price"]
  temp["decimals"] = asset["last_sale"]["payment_token"]["decimals"]
  temp["eth_price"] = asset["last_sale"]["payment_token"]["eth_price"]  
  temp["usd_price"] = asset["last_sale"]["payment_token"]["usd_price"]
  i = 0
  #for trait in asset["traits"]:
    #temp[f"trait_type_{i}"] = trait["trait_type"]
    #temp[f"trait_count_{i}"] = trait["trait_count"]
    #i += 1
  data.append(temp)

# %%
df = pd.DataFrame(data)
df
# Out:
#                 name      id  ...          eth_price                usd_price
# 0   CryptoPunk #7804  176783  ...  1.000000000000000  3584.900000000000091000
# 1   CryptoPunk #3100  176563  ...  1.000000000000000  3584.900000000000091000
# 2   CryptoPunk #5217  178333  ...  1.000000000000000  3584.900000000000091000
# 3   CryptoPunk #8857  177099  ...  1.000000000000000  3584.900000000000091000
# 4   CryptoPunk #2140  169977  ...  1.000000000000000  3584.900000000000091000
# 5   CryptoPunk #7252  177080  ...  1.000000000000000  3584.900000000000091000
# 6   CryptoPunk #2338  178953  ...  1.000000000000000  3584.900000000000091000
# 7   CryptoPunk #6275  177214  ...  1.000000000000000  3584.900000000000091000
# 8   CryptoPunk #8888  179674  ...  1.000000000000000  3584.900000000000091000
# 9   CryptoPunk #3831  178373  ...  1.000000000000000  3584.900000000000091000
# 10  CryptoPunk #6649  177054  ...  1.000000000000000  3584.900000000000091000
# ...
